// %%
1 in 1..3
// Out:
// [1, 2, 3]

// %%
(1..3).toList()
// Out:
// 42

// %%
// 降序闭区间 downTo
1 in 3 downTo 1
// Out:
// true

// %%
// 左闭右开 until
1 in 1 until 3
// Out:
// true

// %%
3 in 3 until 2
// Out:
// false

// %%
3 in 1 until 3
// Out:
// false

// %%
2 in 1..3
// Out:
// true

// %%
2 !in 1..3
// Out:
// false

// %%
'x' in 'a'..'z'
// Out:
// false
